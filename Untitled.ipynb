# %%
a=5
print(a)
# Out:
# 5

# %%
pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/1c/19/bf19123baf16a55fd38cbb100b5a49380b9b6db7279987034689d11254c7/yfinance-0.2.32-py2.py3-none-any.whl.metadata
#   Using cached yfinance-0.2.32-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#   Using cached frozendict-2.3.8-py311-none-any.whl (14 kB)
# ...
#   Using cached peewee-3.17.0.tar.gz (2.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# ...
#    ---------------------------------------- 0.0/69.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/69.0 kB ? eta -:--:--
# ...

# %% [markdown]
# # Import yahoo finance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL",start="2010-01-01",end="2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478998
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490201
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386965
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375156
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417540
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127060
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307251
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339417
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889572
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.207779
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a=[1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
ticker=["RELIANCE.NS","^NSEI","TATAMOTORS.NS","HDFCBANK.NS","ADANIENT.NS","SUZLON.NS","ITC.NS","ICICIBANK.NS","ACC.NS","DMART.NS","MANKIND.NS","LANCER.BO","GODHA.NS"]

# %%
stocks = yf.download(ticker,start="2010-01-01",end="2023-05-05")
# Out:
# [*********************100%%**********************]  13 of 13 completed
# 1 Failed download:
# ['MANKIND.NS']: Exception("%ticker%: Data doesn't exist for startDate = 1262284200, endDate = 1683225000")

# %%
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2010-01-04   722.450745    57.267574          NaN      NaN   153.989578
# 2010-01-05   713.079956    58.592743          NaN      NaN   154.125015
# 2010-01-06   717.706116    64.375305          NaN      NaN   154.228806
# 2010-01-07   722.252991    61.718628          NaN      NaN   154.630539
# 2010-01-08   721.304199    62.498501          NaN      NaN   154.833679
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049      1.2  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951      1.2  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902      1.2  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000      1.2  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000      1.2  1708.210449
#
# ...

# %%
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2010-01-04   722.450745    57.267574          NaN      NaN   153.989578
# 2010-01-05   713.079956    58.592743          NaN      NaN   154.125015
# 2010-01-06   717.706116    64.375305          NaN      NaN   154.228806
# 2010-01-07   722.252991    61.718628          NaN      NaN   154.630539
# 2010-01-08   721.304199    62.498501          NaN      NaN   154.833679
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049      1.2  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951      1.2  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902      1.2  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000      1.2  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000      1.2  1708.210449
#
# ...

# %% [markdown]
# # stocks dates from downloads

# %%
stocks = yf.download(ticker,start="2020-01-01",end="2023-05-05")
# Out:
# [*********************100%%**********************]  13 of 13 completed
# 1 Failed download:
# ['MANKIND.NS']: Exception("%ticker%: Data doesn't exist for startDate = 1577817000, endDate = 1683225000")

# %%
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2020-01-01  1339.945190   206.013153  1828.500000    0.615  1244.189697
# 2020-01-02  1389.212891   209.333527  1824.199951    0.615  1252.120361
# 2020-01-03  1373.627686   206.459167  1843.550049    0.615  1234.264160
# 2020-01-06  1335.711792   197.786484  1789.900024    0.615  1207.552856
# 2020-01-07  1354.739502   202.246719  1815.750000    0.615  1226.674072
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049    1.200  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951    1.200  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902    1.200  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000    1.200  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000    1.200  1708.210449
#
# ...

# %%
stocks.head()
# Out:
#                        Adj Close                                    \
#                           ACC.NS ADANIENT.NS     DMART.NS GODHA.NS
# Date
# 2020-01-01 00:00:00  1339.945190  206.013153  1828.500000    0.615
# 2020-01-02 00:00:00  1389.212891  209.333527  1824.199951    0.615
# 2020-01-03 00:00:00  1373.627686  206.459167  1843.550049    0.615
# 2020-01-06 00:00:00  1335.711792  197.786484  1789.900024    0.615
# 2020-01-07 00:00:00  1354.739502  202.246719  1815.750000    0.615
#
#                                                                       \
#                      HDFCBANK.NS ICICIBANK.NS      ITC.NS  LANCER.BO
# Date
# 2020-01-01 00:00:00  1244.189697   527.647278  201.114227  35.489487
# 2020-01-02 00:00:00  1252.120361   531.431946  202.592438  36.689133
# 2020-01-03 00:00:00  1234.264160   529.711609  201.452133  37.988747
# 2020-01-06 00:00:00  1207.552856   516.784668  198.580261  37.538879
# ...

# %%
stocks.tail()
# Out:
#                        Adj Close                                     \
#                           ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS
# Date
# 2023-04-27 00:00:00  1733.103760  1852.124756  3500.800049      1.2
# 2023-04-28 00:00:00  1744.982178  1923.988647  3511.949951      1.2
# 2023-05-02 00:00:00  1746.269043  1918.891235  3545.899902      1.2
# 2023-05-03 00:00:00  1725.927246  1838.081665  3554.000000      1.2
# 2023-05-04 00:00:00  1748.397217  1910.295532  3584.500000      1.2
#
#                                                                        \
#                      HDFCBANK.NS ICICIBANK.NS      ITC.NS   LANCER.BO
# Date
# 2023-04-27 00:00:00  1661.941040   910.852478  413.452667  149.000000
# 2023-04-28 00:00:00  1668.466187   910.158203  422.944183  149.850006
# 2023-05-02 00:00:00  1668.120117   914.571838  421.850952  150.649994
# 2023-05-03 00:00:00  1673.953247   915.315735  424.534393  148.550003
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 829 entries, 2020-01-01 00:00:00 to 2023-05-04 00:00:00
# Data columns (total 78 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (Adj Close, ACC.NS)         829 non-null    float64
#  1   (Adj Close, ADANIENT.NS)    829 non-null    float64
#  2   (Adj Close, DMART.NS)       829 non-null    float64
#  3   (Adj Close, GODHA.NS)       829 non-null    float64
#  4   (Adj Close, HDFCBANK.NS)    829 non-null    float64
#  5   (Adj Close, ICICIBANK.NS)   829 non-null    float64
#  6   (Adj Close, ITC.NS)         829 non-null    float64
#  7   (Adj Close, LANCER.BO)      829 non-null    float64
#  8   (Adj Close, MANKIND.NS)     0 non-null      float64
#  9   (Adj Close, RELIANCE.NS)    829 non-null    float64
#  10  (Adj Close, SUZLON.NS)      829 non-null    float64
#  11  (Adj Close, TATAMOTORS.NS)  829 non-null    float64
# ...

# %% [markdown]
# # make the data availabe offline in csv

# %%
 stocks.to_csv("stocks.csv")

# %%
 stocks = pd.read_csv("stocks.csv")

# %%
stocks
# Out:
#               Unnamed: 0           Adj Close         Adj Close.1  \
# 0                    NaN              ACC.NS         ADANIENT.NS
# 1                   Date                 NaN                 NaN
# 2    2020-01-01 00:00:00  1339.9451904296875  206.01315307617188
# 3    2020-01-02 00:00:00      1389.212890625  209.33352661132812
# 4    2020-01-03 00:00:00   1373.627685546875  206.45916748046875
# ..                   ...                 ...                 ...
# 826  2023-04-27 00:00:00   1733.103759765625   1852.124755859375
# 827  2023-04-28 00:00:00   1744.982177734375  1923.9886474609375
# 828  2023-05-02 00:00:00    1746.26904296875  1918.8912353515625
# 829  2023-05-03 00:00:00    1725.92724609375  1838.0816650390625
# 830  2023-05-04 00:00:00   1748.397216796875  1910.2955322265625
#
#            Adj Close.2         Adj Close.3         Adj Close.4  \
# 0             DMART.NS            GODHA.NS         HDFCBANK.NS
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stocks
# Out:
#               Unnamed: 0           Adj Close         Adj Close.1  \
# 0                    NaN              ACC.NS         ADANIENT.NS
# 1                   Date                 NaN                 NaN
# 2    2020-01-01 00:00:00  1339.9451904296875  206.01315307617188
# 3    2020-01-02 00:00:00      1389.212890625  209.33352661132812
# 4    2020-01-03 00:00:00   1373.627685546875  206.45916748046875
# ..                   ...                 ...                 ...
# 826  2023-04-27 00:00:00   1733.103759765625   1852.124755859375
# 827  2023-04-28 00:00:00   1744.982177734375  1923.9886474609375
# 828  2023-05-02 00:00:00    1746.26904296875  1918.8912353515625
# 829  2023-05-03 00:00:00    1725.92724609375  1838.0816650390625
# 830  2023-05-04 00:00:00   1748.397216796875  1910.2955322265625
#
#            Adj Close.2         Adj Close.3         Adj Close.4  \
# 0             DMART.NS            GODHA.NS         HDFCBANK.NS
# ...

# %%
stocks
# Out:
#               Unnamed: 0           Adj Close         Adj Close.1  \
# 0                    NaN              ACC.NS         ADANIENT.NS
# 1                   Date                 NaN                 NaN
# 2    2020-01-01 00:00:00  1339.9451904296875  206.01315307617188
# 3    2020-01-02 00:00:00      1389.212890625  209.33352661132812
# 4    2020-01-03 00:00:00   1373.627685546875  206.45916748046875
# ..                   ...                 ...                 ...
# 826  2023-04-27 00:00:00   1733.103759765625   1852.124755859375
# 827  2023-04-28 00:00:00   1744.982177734375  1923.9886474609375
# 828  2023-05-02 00:00:00    1746.26904296875  1918.8912353515625
# 829  2023-05-03 00:00:00    1725.92724609375  1838.0816650390625
# 830  2023-05-04 00:00:00   1748.397216796875  1910.2955322265625
#
#            Adj Close.2         Adj Close.3         Adj Close.4  \
# 0             DMART.NS            GODHA.NS         HDFCBANK.NS
# ...

# %%
 stocks = pd.read_csv("stocks.csv")
stocks
# Out:
#               Unnamed: 0           Adj Close         Adj Close.1  \
# 0                    NaN              ACC.NS         ADANIENT.NS
# 1                   Date                 NaN                 NaN
# 2    2020-01-01 00:00:00  1339.9451904296875  206.01315307617188
# 3    2020-01-02 00:00:00      1389.212890625  209.33352661132812
# 4    2020-01-03 00:00:00   1373.627685546875  206.45916748046875
# ..                   ...                 ...                 ...
# 826  2023-04-27 00:00:00   1733.103759765625   1852.124755859375
# 827  2023-04-28 00:00:00   1744.982177734375  1923.9886474609375
# 828  2023-05-02 00:00:00    1746.26904296875  1918.8912353515625
# 829  2023-05-03 00:00:00    1725.92724609375  1838.0816650390625
# 830  2023-05-04 00:00:00   1748.397216796875  1910.2955322265625
#
#            Adj Close.2         Adj Close.3         Adj Close.4  \
# 0             DMART.NS            GODHA.NS         HDFCBANK.NS
# ...

# %%
 stocks = pd.read_csv("stocks.csv",header=[0,1])
stocks
# Out:
#       Unnamed: 0_level_0    Adj Close                                     \
#       Unnamed: 0_level_1       ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS
# 0                   Date          NaN          NaN          NaN      NaN
# 1    2020-01-01 00:00:00  1339.945190   206.013153  1828.500000    0.615
# 2    2020-01-02 00:00:00  1389.212891   209.333527  1824.199951    0.615
# 3    2020-01-03 00:00:00  1373.627686   206.459167  1843.550049    0.615
# 4    2020-01-06 00:00:00  1335.711792   197.786484  1789.900024    0.615
# ..                   ...          ...          ...          ...      ...
# 825  2023-04-27 00:00:00  1733.103760  1852.124756  3500.800049    1.200
# 826  2023-04-28 00:00:00  1744.982178  1923.988647  3511.949951    1.200
# 827  2023-05-02 00:00:00  1746.269043  1918.891235  3545.899902    1.200
# 828  2023-05-03 00:00:00  1725.927246  1838.081665  3554.000000    1.200
# 829  2023-05-04 00:00:00  1748.397217  1910.295532  3584.500000    1.200
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0', 'Unnamed: 0_level_1'),
#             (         'Adj Close',             'ACC.NS'),
#             (         'Adj Close',        'ADANIENT.NS'),
#             (         'Adj Close',           'DMART.NS'),
#             (         'Adj Close',           'GODHA.NS'),
#             (         'Adj Close',        'HDFCBANK.NS'),
#             (         'Adj Close',       'ICICIBANK.NS'),
#             (         'Adj Close',             'ITC.NS'),
#             (         'Adj Close',          'LANCER.BO'),
#             (         'Adj Close',         'MANKIND.NS'),
#             (         'Adj Close',        'RELIANCE.NS'),
#             (         'Adj Close',          'SUZLON.NS'),
#             (         'Adj Close',      'TATAMOTORS.NS'),
#             (         'Adj Close',              '^NSEI'),
#             (             'Close',             'ACC.NS'),
#             (             'Close',        'ADANIENT.NS'),
# ...

# %%
stocks
# Out:
#       Unnamed: 0_level_0    Adj Close                                     \
#       Unnamed: 0_level_1       ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS
# 0                   Date          NaN          NaN          NaN      NaN
# 1    2020-01-01 00:00:00  1339.945190   206.013153  1828.500000    0.615
# 2    2020-01-02 00:00:00  1389.212891   209.333527  1824.199951    0.615
# 3    2020-01-03 00:00:00  1373.627686   206.459167  1843.550049    0.615
# 4    2020-01-06 00:00:00  1335.711792   197.786484  1789.900024    0.615
# ..                   ...          ...          ...          ...      ...
# 825  2023-04-27 00:00:00  1733.103760  1852.124756  3500.800049    1.200
# 826  2023-04-28 00:00:00  1744.982178  1923.988647  3511.949951    1.200
# 827  2023-05-02 00:00:00  1746.269043  1918.891235  3545.899902    1.200
# 828  2023-05-03 00:00:00  1725.927246  1838.081665  3554.000000    1.200
# 829  2023-05-04 00:00:00  1748.397217  1910.295532  3584.500000    1.200
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0', 'Unnamed: 0_level_1'),
#             (         'Adj Close',             'ACC.NS'),
#             (         'Adj Close',        'ADANIENT.NS'),
#             (         'Adj Close',           'DMART.NS'),
#             (         'Adj Close',           'GODHA.NS'),
#             (         'Adj Close',        'HDFCBANK.NS'),
#             (         'Adj Close',       'ICICIBANK.NS'),
#             (         'Adj Close',             'ITC.NS'),
#             (         'Adj Close',          'LANCER.BO'),
#             (         'Adj Close',         'MANKIND.NS'),
#             (         'Adj Close',        'RELIANCE.NS'),
#             (         'Adj Close',          'SUZLON.NS'),
#             (         'Adj Close',      'TATAMOTORS.NS'),
#             (         'Adj Close',              '^NSEI'),
#             (             'Close',             'ACC.NS'),
#             (             'Close',        'ADANIENT.NS'),
# ...

# %%
 stocks = pd.read_csv("stocks.csv",header=[0,1],index_col=[0], parse_dates=[0])
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2020-01-01  1339.945190   206.013153  1828.500000    0.615  1244.189697
# 2020-01-02  1389.212891   209.333527  1824.199951    0.615  1252.120361
# 2020-01-03  1373.627686   206.459167  1843.550049    0.615  1234.264160
# 2020-01-06  1335.711792   197.786484  1789.900024    0.615  1207.552856
# 2020-01-07  1354.739502   202.246719  1815.750000    0.615  1226.674072
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049    1.200  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951    1.200  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902    1.200  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000    1.200  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000    1.200  1708.210449
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',        'ACC.NS'),
#             ('Adj Close',   'ADANIENT.NS'),
#             ('Adj Close',      'DMART.NS'),
#             ('Adj Close',      'GODHA.NS'),
#             ('Adj Close',   'HDFCBANK.NS'),
#             ('Adj Close',  'ICICIBANK.NS'),
#             ('Adj Close',        'ITC.NS'),
#             ('Adj Close',     'LANCER.BO'),
#             ('Adj Close',    'MANKIND.NS'),
#             ('Adj Close',   'RELIANCE.NS'),
#             ('Adj Close',     'SUZLON.NS'),
#             ('Adj Close', 'TATAMOTORS.NS'),
#             ('Adj Close',         '^NSEI'),
#             (    'Close',        'ACC.NS'),
#             (    'Close',   'ADANIENT.NS'),
#             (    'Close',      'DMART.NS'),
#             (    'Close',      'GODHA.NS'),
#             (    'Close',   'HDFCBANK.NS'),
#             (    'Close',  'ICICIBANK.NS'),
#             (    'Close',        'ITC.NS'),
#             (    'Close',     'LANCER.BO'),
# ...

# %%
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([       ('Adj Close', 'ACC.NS'),   ('Adj Close', 'ADANIENT.NS'),
#             ('Adj Close', 'DMART.NS'),      ('Adj Close', 'GODHA.NS'),
#          ('Adj Close', 'HDFCBANK.NS'),  ('Adj Close', 'ICICIBANK.NS'),
#               ('Adj Close', 'ITC.NS'),     ('Adj Close', 'LANCER.BO'),
#           ('Adj Close', 'MANKIND.NS'),   ('Adj Close', 'RELIANCE.NS'),
#            ('Adj Close', 'SUZLON.NS'), ('Adj Close', 'TATAMOTORS.NS'),
#                ('Adj Close', '^NSEI'),            ('Close', 'ACC.NS'),
#              ('Close', 'ADANIENT.NS'),          ('Close', 'DMART.NS'),
#                 ('Close', 'GODHA.NS'),       ('Close', 'HDFCBANK.NS'),
#             ('Close', 'ICICIBANK.NS'),            ('Close', 'ITC.NS'),
#                ('Close', 'LANCER.BO'),        ('Close', 'MANKIND.NS'),
#              ('Close', 'RELIANCE.NS'),         ('Close', 'SUZLON.NS'),
#            ('Close', 'TATAMOTORS.NS'),             ('Close', '^NSEI'),
# ...

# %%
stocks.describe()
# Out:
#        (Adj Close, ACC.NS)  (Adj Close, ADANIENT.NS)  (Adj Close, DMART.NS)  \
# count           829.000000                829.000000             829.000000
# mean           1855.802639               1474.461064            3328.383237
# std             428.146784               1119.365446             876.139959
# min             854.341919                120.708160            1789.900024
# 25%            1537.854370                329.576172            2392.199951
# 50%            1912.910522               1492.020020            3416.949951
# 75%            2207.593262               2044.509033            4073.550049
# max            2719.849854               4163.219727            5323.750000
#
#        (Adj Close, GODHA.NS)  (Adj Close, HDFCBANK.NS)  \
# count             829.000000                829.000000
# mean                3.791261               1363.028316
# std                 4.772271                211.847224
# min                 0.615000                747.039246
# ...

# %%
stocks
# Out:
#             (Adj Close, ACC.NS)  (Adj Close, ADANIENT.NS)  \
# Date
# 2020-01-01          1339.945190                206.013153
# 2020-01-02          1389.212891                209.333527
# 2020-01-03          1373.627686                206.459167
# 2020-01-06          1335.711792                197.786484
# 2020-01-07          1354.739502                202.246719
# ...                         ...                       ...
# 2023-04-27          1733.103760               1852.124756
# 2023-04-28          1744.982178               1923.988647
# 2023-05-02          1746.269043               1918.891235
# 2023-05-03          1725.927246               1838.081665
# 2023-05-04          1748.397217               1910.295532
#
#             (Adj Close, DMART.NS)  (Adj Close, GODHA.NS)  \
# Date
# 2020-01-01            1828.500000                  0.615
# 2020-01-02            1824.199951                  0.615
# 2020-01-03            1843.550049                  0.615
# ...

# %%
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([       ('Adj Close', 'ACC.NS'),   ('Adj Close', 'ADANIENT.NS'),
#             ('Adj Close', 'DMART.NS'),      ('Adj Close', 'GODHA.NS'),
#          ('Adj Close', 'HDFCBANK.NS'),  ('Adj Close', 'ICICIBANK.NS'),
#               ('Adj Close', 'ITC.NS'),     ('Adj Close', 'LANCER.BO'),
#           ('Adj Close', 'MANKIND.NS'),   ('Adj Close', 'RELIANCE.NS'),
#            ('Adj Close', 'SUZLON.NS'), ('Adj Close', 'TATAMOTORS.NS'),
#                ('Adj Close', '^NSEI'),            ('Close', 'ACC.NS'),
#              ('Close', 'ADANIENT.NS'),          ('Close', 'DMART.NS'),
#                 ('Close', 'GODHA.NS'),       ('Close', 'HDFCBANK.NS'),
#             ('Close', 'ICICIBANK.NS'),            ('Close', 'ITC.NS'),
#                ('Close', 'LANCER.BO'),        ('Close', 'MANKIND.NS'),
#              ('Close', 'RELIANCE.NS'),         ('Close', 'SUZLON.NS'),
#            ('Close', 'TATAMOTORS.NS'),             ('Close', '^NSEI'),
# ...

# %%
stocks
# Out:
#             (Adj Close, ACC.NS)  (Adj Close, ADANIENT.NS)  \
# Date
# 2020-01-01          1339.945190                206.013153
# 2020-01-02          1389.212891                209.333527
# 2020-01-03          1373.627686                206.459167
# 2020-01-06          1335.711792                197.786484
# 2020-01-07          1354.739502                202.246719
# ...                         ...                       ...
# 2023-04-27          1733.103760               1852.124756
# 2023-04-28          1744.982178               1923.988647
# 2023-05-02          1746.269043               1918.891235
# 2023-05-03          1725.927246               1838.081665
# 2023-05-04          1748.397217               1910.295532
#
#             (Adj Close, DMART.NS)  (Adj Close, GODHA.NS)  \
# Date
# 2020-01-01            1828.500000                  0.615
# 2020-01-02            1824.199951                  0.615
# 2020-01-03            1843.550049                  0.615
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2020-01-01  1339.945190   206.013153  1828.500000    0.615  1244.189697
# 2020-01-02  1389.212891   209.333527  1824.199951    0.615  1252.120361
# 2020-01-03  1373.627686   206.459167  1843.550049    0.615  1234.264160
# 2020-01-06  1335.711792   197.786484  1789.900024    0.615  1207.552856
# 2020-01-07  1354.739502   202.246719  1815.750000    0.615  1226.674072
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049    1.200  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951    1.200  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902    1.200  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000    1.200  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000    1.200  1708.210449
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',        'ACC.NS'),
#             ('Adj Close',   'ADANIENT.NS'),
#             ('Adj Close',      'DMART.NS'),
#             ('Adj Close',      'GODHA.NS'),
#             ('Adj Close',   'HDFCBANK.NS'),
#             ('Adj Close',  'ICICIBANK.NS'),
#             ('Adj Close',        'ITC.NS'),
#             ('Adj Close',     'LANCER.BO'),
#             ('Adj Close',    'MANKIND.NS'),
#             ('Adj Close',   'RELIANCE.NS'),
#             ('Adj Close',     'SUZLON.NS'),
#             ('Adj Close', 'TATAMOTORS.NS'),
#             ('Adj Close',         '^NSEI'),
#             (    'Close',        'ACC.NS'),
#             (    'Close',   'ADANIENT.NS'),
#             (    'Close',      'DMART.NS'),
#             (    'Close',      'GODHA.NS'),
#             (    'Close',   'HDFCBANK.NS'),
#             (    'Close',  'ICICIBANK.NS'),
#             (    'Close',        'ITC.NS'),
#             (    'Close',     'LANCER.BO'),
# ...

# %%
 stocks = pd.read_csv("stocks.csv",header=[0,1])
stocks
# Out:
#       Unnamed: 0_level_0    Adj Close                                     \
#       Unnamed: 0_level_1       ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS
# 0                   Date          NaN          NaN          NaN      NaN
# 1    2020-01-01 00:00:00  1339.945190   206.013153  1828.500000    0.615
# 2    2020-01-02 00:00:00  1389.212891   209.333527  1824.199951    0.615
# 3    2020-01-03 00:00:00  1373.627686   206.459167  1843.550049    0.615
# 4    2020-01-06 00:00:00  1335.711792   197.786484  1789.900024    0.615
# ..                   ...          ...          ...          ...      ...
# 825  2023-04-27 00:00:00  1733.103760  1852.124756  3500.800049    1.200
# 826  2023-04-28 00:00:00  1744.982178  1923.988647  3511.949951    1.200
# 827  2023-05-02 00:00:00  1746.269043  1918.891235  3545.899902    1.200
# 828  2023-05-03 00:00:00  1725.927246  1838.081665  3554.000000    1.200
# 829  2023-05-04 00:00:00  1748.397217  1910.295532  3584.500000    1.200
#
# ...

# %%
 stocks = pd.read_csv("stocks.csv")
stocks
# Out:
#               Unnamed: 0           Adj Close         Adj Close.1  \
# 0                    NaN              ACC.NS         ADANIENT.NS
# 1                   Date                 NaN                 NaN
# 2    2020-01-01 00:00:00  1339.9451904296875  206.01315307617188
# 3    2020-01-02 00:00:00      1389.212890625  209.33352661132812
# 4    2020-01-03 00:00:00   1373.627685546875  206.45916748046875
# ..                   ...                 ...                 ...
# 826  2023-04-27 00:00:00   1733.103759765625   1852.124755859375
# 827  2023-04-28 00:00:00   1744.982177734375  1923.9886474609375
# 828  2023-05-02 00:00:00    1746.26904296875  1918.8912353515625
# 829  2023-05-03 00:00:00    1725.92724609375  1838.0816650390625
# 830  2023-05-04 00:00:00   1748.397216796875  1910.2955322265625
#
#            Adj Close.2         Adj Close.3         Adj Close.4  \
# 0             DMART.NS            GODHA.NS         HDFCBANK.NS
# ...

# %%
 stocks = pd.read_csv("stocks.csv",header=[0,1])
stocks
# Out:
#       Unnamed: 0_level_0    Adj Close                                     \
#       Unnamed: 0_level_1       ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS
# 0                   Date          NaN          NaN          NaN      NaN
# 1    2020-01-01 00:00:00  1339.945190   206.013153  1828.500000    0.615
# 2    2020-01-02 00:00:00  1389.212891   209.333527  1824.199951    0.615
# 3    2020-01-03 00:00:00  1373.627686   206.459167  1843.550049    0.615
# 4    2020-01-06 00:00:00  1335.711792   197.786484  1789.900024    0.615
# ..                   ...          ...          ...          ...      ...
# 825  2023-04-27 00:00:00  1733.103760  1852.124756  3500.800049    1.200
# 826  2023-04-28 00:00:00  1744.982178  1923.988647  3511.949951    1.200
# 827  2023-05-02 00:00:00  1746.269043  1918.891235  3545.899902    1.200
# 828  2023-05-03 00:00:00  1725.927246  1838.081665  3554.000000    1.200
# 829  2023-05-04 00:00:00  1748.397217  1910.295532  3584.500000    1.200
#
# ...

# %%
stocks.head()
# Out:
#     Unnamed: 0_level_0    Adj Close                                    \
#     Unnamed: 0_level_1       ACC.NS ADANIENT.NS     DMART.NS GODHA.NS
# 0                 Date          NaN         NaN          NaN      NaN
# 1  2020-01-01 00:00:00  1339.945190  206.013153  1828.500000    0.615
# 2  2020-01-02 00:00:00  1389.212891  209.333527  1824.199951    0.615
# 3  2020-01-03 00:00:00  1373.627686  206.459167  1843.550049    0.615
# 4  2020-01-06 00:00:00  1335.711792  197.786484  1789.900024    0.615
#
#                                                                ...   Volume  \
#    HDFCBANK.NS ICICIBANK.NS      ITC.NS  LANCER.BO MANKIND.NS  ... GODHA.NS
# 0          NaN          NaN         NaN        NaN        NaN  ...      NaN
# 1  1244.189697   527.647278  201.114227  35.489487        NaN  ...      0.0
# 2  1252.120361   531.431946  202.592438  36.689133        NaN  ...      0.0
# 3  1234.264160   529.711609  201.452133  37.988747        NaN  ...      0.0
# ...

# %% [markdown]
# # adjusting the dates

# %%
stocks = pd.read_csv("stocks.csv",header=[0,1],index_col=[0])
stocks
# Out:
#                        Adj Close                                     \
#                           ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS
# Date
# 2020-01-01 00:00:00  1339.945190   206.013153  1828.500000    0.615
# 2020-01-02 00:00:00  1389.212891   209.333527  1824.199951    0.615
# 2020-01-03 00:00:00  1373.627686   206.459167  1843.550049    0.615
# 2020-01-06 00:00:00  1335.711792   197.786484  1789.900024    0.615
# 2020-01-07 00:00:00  1354.739502   202.246719  1815.750000    0.615
# ...                          ...          ...          ...      ...
# 2023-04-27 00:00:00  1733.103760  1852.124756  3500.800049    1.200
# 2023-04-28 00:00:00  1744.982178  1923.988647  3511.949951    1.200
# 2023-05-02 00:00:00  1746.269043  1918.891235  3545.899902    1.200
# 2023-05-03 00:00:00  1725.927246  1838.081665  3554.000000    1.200
# 2023-05-04 00:00:00  1748.397217  1910.295532  3584.500000    1.200
#
#                                                                        \
# ...

# %%
stocks = pd.read_csv("stocks.csv",header=[0,1],index_col=[0],parse_dates=[0])
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2020-01-01  1339.945190   206.013153  1828.500000    0.615  1244.189697
# 2020-01-02  1389.212891   209.333527  1824.199951    0.615  1252.120361
# 2020-01-03  1373.627686   206.459167  1843.550049    0.615  1234.264160
# 2020-01-06  1335.711792   197.786484  1789.900024    0.615  1207.552856
# 2020-01-07  1354.739502   202.246719  1815.750000    0.615  1226.674072
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049    1.200  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951    1.200  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902    1.200  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000    1.200  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000    1.200  1708.210449
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                                     \
#             ACC.NS  ADANIENT.NS     DMART.NS    GODHA.NS  HDFCBANK.NS
# count   829.000000   829.000000   829.000000  829.000000   829.000000
# mean   1855.802639  1474.461064  3328.383237    3.791261  1363.028316
# std     428.146784  1119.365446   876.139959    4.772271   211.847224
# min     854.341919   120.708160  1789.900024    0.615000   747.039246
# 25%    1537.854370   329.576172  2392.199951    1.450000  1248.179321
# 50%    1912.910522  1492.020020  3416.949951    2.020000  1422.289307
# 75%    2207.593262  2044.509033  4073.550049    3.100000  1510.183105
# max    2719.849854  4163.219727  5323.750000   29.150000  1708.210449
#
#                                                                     ...  \
#       ICICIBANK.NS      ITC.NS   LANCER.BO MANKIND.NS  RELIANCE.NS  ...
# count   829.000000  829.000000  829.000000        0.0   829.000000  ...
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                  ACC.NS  ADANIENT.NS     DMART.NS  GODHA.NS  HDFCBANK.NS  \
# Date
# 2020-01-01  1440.099976   207.850006  1828.500000     0.615  1278.599976
# 2020-01-02  1493.050049   211.199997  1824.199951     0.615  1286.750000
# 2020-01-03  1476.300049   208.300003  1843.550049     0.615  1268.400024
# 2020-01-06  1435.550049   199.550003  1789.900024     0.615  1240.949951
# 2020-01-07  1456.000000   204.050003  1815.750000     0.615  1260.599976
# ...                 ...          ...          ...       ...          ...
# 2023-04-27  1750.849976  1853.050049  3500.800049     1.200  1681.000000
# 2023-04-28  1762.849976  1924.949951  3511.949951     1.200  1687.599976
# 2023-05-02  1764.150024  1919.849976  3545.899902     1.200  1687.250000
# 2023-05-03  1743.599976  1839.000000  3554.000000     1.200  1693.150024
# 2023-05-04  1766.300049  1911.250000  3584.500000     1.200  1727.800049
#
#             ICICIBANK.NS      ITC.NS   LANCER.BO  MANKIND.NS  RELIANCE.NS  \
# Date
# ...

# %%
Close=stocks.loc[:,"Close"].copy()

# %%
Close
# Out:
#                  ACC.NS  ADANIENT.NS     DMART.NS  GODHA.NS  HDFCBANK.NS  \
# Date
# 2020-01-01  1440.099976   207.850006  1828.500000     0.615  1278.599976
# 2020-01-02  1493.050049   211.199997  1824.199951     0.615  1286.750000
# 2020-01-03  1476.300049   208.300003  1843.550049     0.615  1268.400024
# 2020-01-06  1435.550049   199.550003  1789.900024     0.615  1240.949951
# 2020-01-07  1456.000000   204.050003  1815.750000     0.615  1260.599976
# ...                 ...          ...          ...       ...          ...
# 2023-04-27  1750.849976  1853.050049  3500.800049     1.200  1681.000000
# 2023-04-28  1762.849976  1924.949951  3511.949951     1.200  1687.599976
# 2023-05-02  1764.150024  1919.849976  3545.899902     1.200  1687.250000
# 2023-05-03  1743.599976  1839.000000  3554.000000     1.200  1693.150024
# 2023-05-04  1766.300049  1911.250000  3584.500000     1.200  1727.800049
#
#             ICICIBANK.NS      ITC.NS   LANCER.BO  MANKIND.NS  RELIANCE.NS  \
# Date
# ...

# %% [markdown]
# # making graphs and charts

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set a Seaborn style
sns.set_style("whitegrid")

# Create your plots using Matplotlib
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Seaborn Style Example')
plt.show()

# %%
Close.plot(figsize=(15,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # normalizing graph by multiplying by 100

# %%
Close.iloc[0,0]
# Out:
# 1440.0999755859375

# %% [markdown]
# ## take intial value of stocks  from 2020-01

# %%
adani = yf.download("ADANIENT.NS",start="2010-01-01",end="2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Close.iloc[0]
# Out:
# ACC.NS            1440.099976
# ADANIENT.NS        207.850006
# DMART.NS          1828.500000
# GODHA.NS             0.615000
# HDFCBANK.NS       1278.599976
# ICICIBANK.NS       536.750000
# ITC.NS             238.100006
# LANCER.BO           35.500000
# MANKIND.NS                NaN
# RELIANCE.NS       1495.424927
# SUZLON.NS            1.900000
# TATAMOTORS.NS      184.449997
# ^NSEI            12182.500000
# Name: 2020-01-01 00:00:00, dtype: float64

# %% [markdown]
# ## divide by inital value and now multiply by 100

# %%
Close.div(Close.iloc[0]).mul(100)
# Out:
#                 ACC.NS  ADANIENT.NS    DMART.NS    GODHA.NS  HDFCBANK.NS  \
# Date
# 2020-01-01  100.000000   100.000000  100.000000  100.000000   100.000000
# 2020-01-02  103.676833   101.611735   99.764832  100.000000   100.637418
# 2020-01-03  102.513719   100.216501  100.823082  100.000000    99.202256
# 2020-01-06   99.684055    96.006734   97.888981  100.000000    97.055371
# 2020-01-07  101.104092    98.171757   99.302707  100.000000    98.592210
# ...                ...          ...         ...         ...          ...
# 2023-04-27  121.578363   891.532352  191.457481  195.121956   131.471925
# 2023-04-28  122.411638   926.124558  192.067266  195.121956   131.988113
# 2023-05-02  122.501913   923.670878  193.923976  195.121956   131.960741
# 2023-05-03  121.074926   884.772647  194.366967  195.121956   132.422185
# 2023-05-04  122.651210   919.533290  196.035001  195.121956   135.132182
#
#             ICICIBANK.NS      ITC.NS   LANCER.BO  MANKIND.NS  RELIANCE.NS  \
# Date
# ...

# %% [markdown]
# # This one below is the new syntax you need to get a single data from column

# %%
Close["ADANIENT.NS"]
# Out:
# Date
# 2020-01-01     207.850006
# 2020-01-02     211.199997
# 2020-01-03     208.300003
# 2020-01-06     199.550003
# 2020-01-07     204.050003
#                  ...
# 2023-04-27    1853.050049
# 2023-04-28    1924.949951
# 2023-05-02    1919.849976
# 2023-05-03    1839.000000
# 2023-05-04    1911.250000
# Name: ADANIENT.NS, Length: 829, dtype: float64

# %%
normclose=Close.div(Close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(20,15),fontsize=20)
# Out:
# <Axes: xlabel='Date'>

# %%
adani = Close["ADANIENT.NS"].copy().to_frame()

# %% [markdown]
# ### to_frame() = to convert a data into dataframe

# %%
adani
# Out:
#             ADANIENT.NS
# Date
# 2020-01-01   207.850006
# 2020-01-02   211.199997
# 2020-01-03   208.300003
# 2020-01-06   199.550003
# 2020-01-07   204.050003
# ...                 ...
# 2023-04-27  1853.050049
# 2023-04-28  1924.949951
# 2023-05-02  1919.849976
# 2023-05-03  1839.000000
# 2023-05-04  1911.250000
#
# [829 rows x 1 columns]

# %% [markdown]
# # shift function moves the  1 cell below of the value

# %%
adani.shift(periods=1)
# Out:
#             ADANIENT.NS
# Date
# 2020-01-01          NaN
# 2020-01-02   207.850006
# 2020-01-03   211.199997
# 2020-01-06   208.300003
# 2020-01-07   199.550003
# ...                 ...
# 2023-04-27  1847.900024
# 2023-04-28  1853.050049
# 2023-05-02  1924.949951
# 2023-05-03  1919.849976
# 2023-05-04  1839.000000
#
# [829 rows x 1 columns]

# %%
adani["lag1"]=adani.shift(periods=1)

# %% [markdown]
# ### new column has been added

# %%
adani
# Out:
#             ADANIENT.NS         lag1
# Date
# 2020-01-01   207.850006          NaN
# 2020-01-02   211.199997   207.850006
# 2020-01-03   208.300003   211.199997
# 2020-01-06   199.550003   208.300003
# 2020-01-07   204.050003   199.550003
# ...                 ...          ...
# 2023-04-27  1853.050049  1847.900024
# 2023-04-28  1924.949951  1853.050049
# 2023-05-02  1919.849976  1924.949951
# 2023-05-03  1839.000000  1919.849976
# 2023-05-04  1911.250000  1839.000000
#
# [829 rows x 2 columns]

# %% [markdown]
# #### subtracting the original vs one row below

# %%
adani["ADANIENT.NS"].sub(adani.lag1)
# Out:
# Date
# 2020-01-01          NaN
# 2020-01-02     3.349991
# 2020-01-03    -2.899994
# 2020-01-06    -8.750000
# 2020-01-07     4.500000
#                 ...
# 2023-04-27     5.150024
# 2023-04-28    71.899902
# 2023-05-02    -5.099976
# 2023-05-03   -80.849976
# 2023-05-04    72.250000
# Length: 829, dtype: float64

# %%
adani["Diff"]=adani["ADANIENT.NS"].sub(adani.lag1)

# %%
adani
# Out:
#             ADANIENT.NS         lag1       Diff
# Date
# 2020-01-01   207.850006          NaN        NaN
# 2020-01-02   211.199997   207.850006   3.349991
# 2020-01-03   208.300003   211.199997  -2.899994
# 2020-01-06   199.550003   208.300003  -8.750000
# 2020-01-07   204.050003   199.550003   4.500000
# ...                 ...          ...        ...
# 2023-04-27  1853.050049  1847.900024   5.150024
# 2023-04-28  1924.949951  1853.050049  71.899902
# 2023-05-02  1919.849976  1924.949951  -5.099976
# 2023-05-03  1839.000000  1919.849976 -80.849976
# 2023-05-04  1911.250000  1839.000000  72.250000
#
# [829 rows x 3 columns]

# %% [markdown]
# ### dividing the closing data(ADANIENT.NS) with lag1 data and then again subtracting it with 1 and multiplying by 100

# %%
adani["%change"]=adani["ADANIENT.NS"].div(adani.lag1).sub(1).mul(100)

# %%
adani
# Out:
#             ADANIENT.NS         lag1       Diff   %change
# Date
# 2020-01-01   207.850006          NaN        NaN       NaN
# 2020-01-02   211.199997   207.850006   3.349991  1.611735
# 2020-01-03   208.300003   211.199997  -2.899994 -1.373103
# 2020-01-06   199.550003   208.300003  -8.750000 -4.200672
# 2020-01-07   204.050003   199.550003   4.500000  2.255074
# ...                 ...          ...        ...       ...
# 2023-04-27  1853.050049  1847.900024   5.150024  0.278696
# 2023-04-28  1924.949951  1853.050049  71.899902  3.880084
# 2023-05-02  1919.849976  1924.949951  -5.099976 -0.264941
# 2023-05-03  1839.000000  1919.849976 -80.849976 -4.211265
# 2023-05-04  1911.250000  1839.000000  72.250000  3.928766
#
# [829 rows x 4 columns]

# %% [markdown]
# ### just using diff function instead of sub which directly subtract no need to make any other column

# %%
adani["diif2"] = adani["ADANIENT.NS"].diff(periods=1)

# %%
adani
# Out:
#             ADANIENT.NS         lag1       Diff   %change      diif2
# Date
# 2020-01-01   207.850006          NaN        NaN       NaN        NaN
# 2020-01-02   211.199997   207.850006   3.349991  1.611735   3.349991
# 2020-01-03   208.300003   211.199997  -2.899994 -1.373103  -2.899994
# 2020-01-06   199.550003   208.300003  -8.750000 -4.200672  -8.750000
# 2020-01-07   204.050003   199.550003   4.500000  2.255074   4.500000
# ...                 ...          ...        ...       ...        ...
# 2023-04-27  1853.050049  1847.900024   5.150024  0.278696   5.150024
# 2023-04-28  1924.949951  1853.050049  71.899902  3.880084  71.899902
# 2023-05-02  1919.849976  1924.949951  -5.099976 -0.264941  -5.099976
# 2023-05-03  1839.000000  1919.849976 -80.849976 -4.211265 -80.849976
# 2023-05-04  1911.250000  1839.000000  72.250000  3.928766  72.250000
#
# [829 rows x 5 columns]

# %% [markdown]
# #### using pct_change instead of percentage change means no need to take diif and subtract one instead use direct function

# %%
adani["%change2"] =adani["ADANIENT.NS"].pct_change(periods=1).mul(100)

# %%
adani
# Out:
#             ADANIENT.NS         lag1       Diff   %change      diif2  %change2
# Date
# 2020-01-01   207.850006          NaN        NaN       NaN        NaN       NaN
# 2020-01-02   211.199997   207.850006   3.349991  1.611735   3.349991  1.611735
# 2020-01-03   208.300003   211.199997  -2.899994 -1.373103  -2.899994 -1.373103
# 2020-01-06   199.550003   208.300003  -8.750000 -4.200672  -8.750000 -4.200672
# 2020-01-07   204.050003   199.550003   4.500000  2.255074   4.500000  2.255074
# ...                 ...          ...        ...       ...        ...       ...
# 2023-04-27  1853.050049  1847.900024   5.150024  0.278696   5.150024  0.278696
# 2023-04-28  1924.949951  1853.050049  71.899902  3.880084  71.899902  3.880084
# 2023-05-02  1919.849976  1924.949951  -5.099976 -0.264941  -5.099976 -0.264941
# 2023-05-03  1839.000000  1919.849976 -80.849976 -4.211265 -80.849976 -4.211265
# 2023-05-04  1911.250000  1839.000000  72.250000  3.928766  72.250000  3.928766
#
# ...

# %% [markdown]
# ### using delete function to delete the whole column

# %%
del adani["lag1"]

# %%
adani
# Out:
#             ADANIENT.NS       Diff   %change      diif2  %change2
# Date
# 2020-01-01   207.850006        NaN       NaN        NaN       NaN
# 2020-01-02   211.199997   3.349991  1.611735   3.349991  1.611735
# 2020-01-03   208.300003  -2.899994 -1.373103  -2.899994 -1.373103
# 2020-01-06   199.550003  -8.750000 -4.200672  -8.750000 -4.200672
# 2020-01-07   204.050003   4.500000  2.255074   4.500000  2.255074
# ...                 ...        ...       ...        ...       ...
# 2023-04-27  1853.050049   5.150024  0.278696   5.150024  0.278696
# 2023-04-28  1924.949951  71.899902  3.880084  71.899902  3.880084
# 2023-05-02  1919.849976  -5.099976 -0.264941  -5.099976 -0.264941
# 2023-05-03  1839.000000 -80.849976 -4.211265 -80.849976 -4.211265
# 2023-05-04  1911.250000  72.250000  3.928766  72.250000  3.928766
#
# [829 rows x 5 columns]

# %% [markdown]
# #### using drop function instead to delete everything

# %%
adani.drop(["Diff", "%change","diif2"], axis=1, inplace=True)

# %%
adani
# Out:
#             ADANIENT.NS  %change2
# Date
# 2020-01-01   207.850006       NaN
# 2020-01-02   211.199997  1.611735
# 2020-01-03   208.300003 -1.373103
# 2020-01-06   199.550003 -4.200672
# 2020-01-07   204.050003  2.255074
# ...                 ...       ...
# 2023-04-27  1853.050049  0.278696
# 2023-04-28  1924.949951  3.880084
# 2023-05-02  1919.849976 -0.264941
# 2023-05-03  1839.000000 -4.211265
# 2023-05-04  1911.250000  3.928766
#
# [829 rows x 2 columns]

# %% [markdown]
# ### using rename function

# %%
adani.rename(columns={'%change2':'change'}, inplace= True)

# %%
adani
# Out:
#             ADANIENT.NS    change
# Date
# 2020-01-01   207.850006       NaN
# 2020-01-02   211.199997  1.611735
# 2020-01-03   208.300003 -1.373103
# 2020-01-06   199.550003 -4.200672
# 2020-01-07   204.050003  2.255074
# ...                 ...       ...
# 2023-04-27  1853.050049  0.278696
# 2023-04-28  1924.949951  3.880084
# 2023-05-02  1919.849976 -0.264941
# 2023-05-03  1839.000000 -4.211265
# 2023-05-04  1911.250000  3.928766
#
# [829 rows x 2 columns]

# %% [markdown]
# #### resample last date means all the month end day when the stock was at the price

# %%
adani["ADANIENT.NS"].resample("M").last()
# Out:
# Date
# 2020-01-31     229.449997
# 2020-02-29     218.649994
# 2020-03-31     137.600006
# 2020-04-30     141.399994
# 2020-05-31     148.350006
# 2020-06-30     156.250000
# 2020-07-31     175.250000
# 2020-08-31     279.549988
# 2020-09-30     297.100006
# 2020-10-31     339.700012
# 2020-11-30     398.399994
# 2020-12-31     479.549988
# 2021-01-31     506.649994
# 2021-02-28     833.650024
# 2021-03-31    1031.150024
# 2021-04-30    1158.699951
# 2021-05-31    1316.300049
# 2021-06-30    1507.550049
# 2021-07-31    1420.250000
# 2021-08-31    1587.599976
# 2021-09-30    1468.099976
# 2021-10-31    1423.599976
# 2021-11-30    1662.849976
# 2021-12-31    1709.449951
# 2022-01-31    1714.949951
# 2022-02-28    1644.449951
# 2022-03-31    2014.750000
# 2022-04-30    2332.000000
# 2022-05-31    2167.550049
# 2022-06-30    2190.899902
# 2022-07-31    2569.199951
# 2022-08-31    3194.350098
# 2022-09-30    3455.750000
# 2022-10-31    3347.449951
# 2022-11-30    3917.899902
# ...

# %%
adani.drop(["change"], axis=1, inplace=True)

# %%
ret=adani.pct_change().dropna()

# %%
ret
# Out:
#             ADANIENT.NS
# Date
# 2020-01-02     0.016117
# 2020-01-03    -0.013731
# 2020-01-06    -0.042007
# 2020-01-07     0.022551
# 2020-01-08    -0.012497
# ...                 ...
# 2023-04-27     0.002787
# 2023-04-28     0.038801
# 2023-05-02    -0.002649
# 2023-05-03    -0.042113
# 2023-05-04     0.039288
#
# [828 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 828 entries, 2020-01-02 to 2023-05-04
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ADANIENT.NS  828 non-null    float64
# dtypes: float64(1)
# memory usage: 12.9 KB

# %%
ret.plot(kind="hist",figsize=(12,8),bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# ADANIENT.NS    0.003359
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# ADANIENT.NS    0.001322
# dtype: float64

# %%
std_daily=np.sqrt(var_daily)

# %%
std_daily
# Out:
# ADANIENT.NS    0.036359
# dtype: float64

# %%
ret.std()
# Out:
# ADANIENT.NS    0.036359
# dtype: float64

# %% [markdown]
# ### multipled by 252 because 252 working days when stock exchange is open

# %%
annual_mean_ret=daily_mean_ret*252

# %%
annual_mean_ret
# Out:
# ADANIENT.NS    0.846579
# dtype: float64

# %%
annual_var_ret=var_daily*252

# %%
annual_var_ret
# Out:
# ADANIENT.NS    0.333137
# dtype: float64

# %%
annual_std_returns=np.sqrt(annual_var_ret)

# %%
annual_std_returns
# Out:
# ADANIENT.NS    0.57718
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# ADANIENT.NS    0.57718
# dtype: float64

# %%
ticker=["RELIANCE.NS","TATAMOTORS.NS","HDFCBANK.NS","ADANIENT.NS","SUZLON.NS","ITC.NS","ICICIBANK.NS","ACC.NS","DMART.NS","MANKIND.NS","LANCER.BO"]

# %%
stocks
# Out:
#               Adj Close                                                  \
#                  ACC.NS  ADANIENT.NS     DMART.NS GODHA.NS  HDFCBANK.NS
# Date
# 2020-01-01  1339.945190   206.013153  1828.500000    0.615  1244.189697
# 2020-01-02  1389.212891   209.333527  1824.199951    0.615  1252.120361
# 2020-01-03  1373.627686   206.459167  1843.550049    0.615  1234.264160
# 2020-01-06  1335.711792   197.786484  1789.900024    0.615  1207.552856
# 2020-01-07  1354.739502   202.246719  1815.750000    0.615  1226.674072
# ...                 ...          ...          ...      ...          ...
# 2023-04-27  1733.103760  1852.124756  3500.800049    1.200  1661.941040
# 2023-04-28  1744.982178  1923.988647  3511.949951    1.200  1668.466187
# 2023-05-02  1746.269043  1918.891235  3545.899902    1.200  1668.120117
# 2023-05-03  1725.927246  1838.081665  3554.000000    1.200  1673.953247
# 2023-05-04  1748.397217  1910.295532  3584.500000    1.200  1708.210449
#
# ...

# %%
close=stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
ret=close.pct_change()

# %%
ret.describe().T
# Out:
#                count      mean       std       min       25%       50%  \
# ACC.NS         828.0  0.000454  0.020285 -0.132036 -0.009926  0.001040
# ADANIENT.NS    828.0  0.003359  0.036359 -0.281970 -0.009581  0.003167
# DMART.NS       828.0  0.001034  0.021053 -0.080009 -0.009848  0.000722
# GODHA.NS       828.0  0.001405  0.034607 -0.098039 -0.029990  0.000000
# HDFCBANK.NS    828.0  0.000545  0.019018 -0.126069 -0.008796  0.000439
# ICICIBANK.NS   828.0  0.000921  0.023045 -0.178478 -0.009789  0.001343
# ITC.NS         828.0  0.000870  0.018415 -0.120798 -0.007436  0.000593
# LANCER.BO      828.0  0.003276  0.049961 -0.665959 -0.020271  0.000000
# MANKIND.NS       0.0       NaN       NaN       NaN       NaN       NaN
# RELIANCE.NS    828.0  0.000816  0.021037 -0.131539 -0.009584  0.000992
# SUZLON.NS      828.0  0.002600  0.039777 -0.137283 -0.022409  0.000000
# TATAMOTORS.NS  828.0  0.001619  0.030595 -0.143596 -0.012733  0.001747
# ...

# %%
summary=ret.describe().T.loc[:,("mean","std")]
summary
# Out:
#                    mean       std
# ACC.NS         0.000454  0.020285
# ADANIENT.NS    0.003359  0.036359
# DMART.NS       0.001034  0.021053
# GODHA.NS       0.001405  0.034607
# HDFCBANK.NS    0.000545  0.019018
# ICICIBANK.NS   0.000921  0.023045
# ITC.NS         0.000870  0.018415
# LANCER.BO      0.003276  0.049961
# MANKIND.NS          NaN       NaN
# RELIANCE.NS    0.000816  0.021037
# SUZLON.NS      0.002600  0.039777
# TATAMOTORS.NS  0.001619  0.030595
# ^NSEI          0.000583  0.013662

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#                    mean       std
# ACC.NS         0.114334  0.322008
# ADANIENT.NS    0.846579  0.577180
# DMART.NS       0.260570  0.334205
# GODHA.NS       0.354179  0.549373
# HDFCBANK.NS    0.137269  0.301904
# ICICIBANK.NS   0.232008  0.365834
# ITC.NS         0.219140  0.292322
# LANCER.BO      0.825533  0.793106
# MANKIND.NS          NaN       NaN
# RELIANCE.NS    0.205572  0.333954
# SUZLON.NS      0.655115  0.631436
# TATAMOTORS.NS  0.408051  0.485680
# ^NSEI          0.146937  0.216875

# %% [markdown]
# #####  for i in summary.index means start from i th index
# ##### like it starts from acc to tatamotors

# %% [markdown]
# ##### plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
# ##### means plot xy as x and y as with i index and continue in for loop for next row

# %%
fruits=["aaple","banana","mango"]
for i in fruits:
    print(i)
# Out:
# aaple
# banana
# mango

# %%
fruits[1]
# Out:
# 'banana'

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("annual risk(std)",fontsize=15)
plt.ylabel("annual returns",fontsize=15)
plt.title("Risk/Return",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %% [markdown]
# ### coorelation and covariance

# %% [markdown]
# # formula of coorelation and covariance was taught to us in 4th sem so nothing diff

# %%
ret
# Out:
#               ACC.NS  ADANIENT.NS  DMART.NS  GODHA.NS  HDFCBANK.NS  \
# Date
# 2020-01-01       NaN          NaN       NaN       NaN          NaN
# 2020-01-02  0.036768     0.016117 -0.002352       0.0     0.006374
# 2020-01-03 -0.011219    -0.013731  0.010607       0.0    -0.014261
# 2020-01-06 -0.027603    -0.042007 -0.029101       0.0    -0.021641
# 2020-01-07  0.014245     0.022551  0.014442       0.0     0.015835
# ...              ...          ...       ...       ...          ...
# 2023-04-27  0.006988     0.002787  0.011324       0.0     0.005503
# 2023-04-28  0.006854     0.038801  0.003185       0.0     0.003926
# 2023-05-02  0.000737    -0.002649  0.009667       0.0    -0.000207
# 2023-05-03 -0.011649    -0.042113  0.002284       0.0     0.003497
# 2023-05-04  0.013019     0.039288  0.008582       0.0     0.020465
#
#             ICICIBANK.NS    ITC.NS  LANCER.BO  MANKIND.NS  RELIANCE.NS  \
# Date
# 2020-01-01           NaN       NaN        NaN         NaN          NaN
# ...

# %% [markdown]
# ## finding covariance

# %%
ret.cov()
# Out:
#                  ACC.NS  ADANIENT.NS  DMART.NS  GODHA.NS  HDFCBANK.NS  \
# ACC.NS         0.000411     0.000328  0.000103  0.000009     0.000138
# ADANIENT.NS    0.000328     0.001322  0.000176  0.000007     0.000215
# DMART.NS       0.000103     0.000176  0.000443  0.000011     0.000128
# GODHA.NS       0.000009     0.000007  0.000011  0.001198    -0.000020
# HDFCBANK.NS    0.000138     0.000215  0.000128 -0.000020     0.000362
# ICICIBANK.NS   0.000179     0.000289  0.000154 -0.000002     0.000299
# ITC.NS         0.000118     0.000142  0.000094 -0.000019     0.000112
# LANCER.BO      0.000138     0.000274  0.000093 -0.000051     0.000068
# MANKIND.NS          NaN          NaN       NaN       NaN          NaN
# RELIANCE.NS    0.000146     0.000251  0.000145  0.000027     0.000186
# SUZLON.NS      0.000136     0.000289  0.000097  0.000060     0.000070
# TATAMOTORS.NS  0.000242     0.000414  0.000232  0.000016     0.000244
# ...

# %% [markdown]
# #### finding coorelation

# %%
ret.corr()
# Out:
#                  ACC.NS  ADANIENT.NS  DMART.NS  GODHA.NS  HDFCBANK.NS  \
# ACC.NS         1.000000     0.444885  0.240216  0.012411     0.357631
# ADANIENT.NS    0.444885     1.000000  0.230338  0.005211     0.310585
# DMART.NS       0.240216     0.230338  1.000000  0.014826     0.319382
# GODHA.NS       0.012411     0.005211  0.014826  1.000000    -0.030193
# HDFCBANK.NS    0.357631     0.310585  0.319382 -0.030193     1.000000
# ICICIBANK.NS   0.382864     0.345366  0.318121 -0.002478     0.681804
# ITC.NS         0.315532     0.211678  0.243691 -0.029464     0.318946
# LANCER.BO      0.136019     0.150932  0.088452 -0.029440     0.071516
# MANKIND.NS          NaN          NaN       NaN       NaN          NaN
# RELIANCE.NS    0.342287     0.328332  0.327966  0.036453     0.465480
# SUZLON.NS      0.168254     0.199796  0.116339  0.043775     0.092620
# TATAMOTORS.NS  0.390575     0.372554  0.360060  0.014758     0.419375
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds", annot=True, annot_kws={"size": 15}, vmax=0.6)
plt.show()

# %% [markdown]
# ## this is a coorelation model you can see nifty50 and tatamotors has a coorelation of 0.62 also reliance 0.71 and hdfc 0.79 also icici 0.8 and  because they are in nifty 50 for a long time and when nifty 50 index grow eventually the company also grow in such a way you can compare each stocks

# %% [markdown]
# ## now we will compare itc and adani there coorelation is 0.21 which is less  because both are from diff setors and also if we want to choose a wide portfolio so if adani goes down it wont affect ITC same goes with lancer and godha if we compare them with reliance or adani

# %% [markdown]
# ## look how hdfc and icici are both coorelated because both come under banking sector

# %% [markdown]
# # Simple RETURNS AND LOG

# %%
df = pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns= df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %% [markdown]
# #### in 2017 the price declined by -0.5 percet and in 2018 it again increased by 0.9

# %% [markdown]
# ### 2017 = 100*-0.5
# ### 2017= -50
# ### 2017= 100-50=50

# %% [markdown]
# ### 2018 = 50*0.9
# ### 2018 = 45
# ### 2018 = 45+50 =90

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %% [markdown]
# ###  simple return mean could be missleading because it shows 0.2  returs per anum that means
# ### 2017=100*0.2+100=120
# ### 2018=120*0.2+100=144
#
# # BUT THE ORIGINAL RETURNS ARE DIFFERENT
#
# ### 2017= true return = 50
# ###             error return =120 (LOSS)
#
# ### 2018= true return = 95
# ###             error return =144 (LOSS)

# %%
logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# ##### *2 is for the years we are calculating for

# %% [markdown]
# #### logreturns.mean() * 2:
#
# #### Multiply the mean of log returns by 2:
# #### -0.025647 * 2 = -0.051294
# #### np.exp(...):
#
# #### Calculate the exponential of the result from step 1:
# #### np.exp(-0.051294) ≈ 0.95010213716
# #### 100 * np.exp(...):
#
# #### Multiply the result from step 2 by 100:
# #### 100 * 0.95010213716 ≈ 95.010213716

# %%
NIFTY = yf.download("^NSEI")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
NIFTY
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2023-11-16  19674.699219  19875.250000  19627.000000  19765.199219
# 2023-11-17  19674.750000  19806.000000  19667.449219  19731.800781
# 2023-11-20  19731.150391  19756.449219  19670.500000  19694.000000
# 2023-11-21  19770.900391  19829.099609  19754.050781  19783.400391
# 2023-11-22  19784.000000  19825.550781  19703.849609  19811.849609
#
#                Adj Close  Volume
# Date
# 2007-09-17   4494.649902       0
# 2007-09-18   4546.200195       0
# 2007-09-19   4732.350098       0
# ...

# %%
#nifty=NIFTY.Close show normal data for good ui refer below one

# %%
nifty=NIFTY.Close.to_frame()

# %%
nifty
# Out:
#                    Close
# Date
# 2007-09-17   4494.649902
# 2007-09-18   4546.200195
# 2007-09-19   4732.350098
# 2007-09-20   4747.549805
# 2007-09-21   4837.549805
# ...                  ...
# 2023-11-16  19765.199219
# 2023-11-17  19731.800781
# 2023-11-20  19694.000000
# 2023-11-21  19783.400391
# 2023-11-22  19811.849609
#
# [3967 rows x 1 columns]

# %%
nifty.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
###"upper left": Places the legend in the upper-left corner of the plot.
##"upper right": Places the legend in the upper-right corner of the plot.
##"lower left": Places the legend in the lower-left corner of the plot.
#"lower right": Places the legend in the lower-right corner of the plot.
#"upper center": Places the legend at the upper-center of the plot.

# %%
nifty_roll=nifty.rolling(window=10)

# %%
nifty_roll=nifty_roll.mean()

# %%
##nifty.rolling(window=10): This creates a Rolling object that encapsulates the logic for a rolling window calculation on the nifty DataFrame or Series with a window size of 10.

##Rolling [window=10,center=False,axis=0,method=single]: 
##This is a representation of the Rolling object with specific parameters. 
##The window size is 10, center=False means the window is right-aligned, axis=0 specifies that the rolling window operates along the rows (if nifty is a DataFrame), and method=single indicates that a single valid observation is sufficient for a window to have a valid value.

# %%
nifty_roll.head(15)
# Out:
#                   Close
# Date
# 2007-09-17          NaN
# 2007-09-18          NaN
# 2007-09-19          NaN
# 2007-09-20          NaN
# 2007-09-21          NaN
# 2007-09-24          NaN
# 2007-09-25          NaN
# 2007-09-26          NaN
# 2007-09-27          NaN
# 2007-09-28  4819.175000
# 2007-10-01  4876.605029
# 2007-10-03  4943.064990
# 2007-10-04  4990.694971
# 2007-10-05  5034.525000
# 2007-10-08  5059.280029

# %% [markdown]
# ###  In the output you provided earlier, the NaN (Not a Number) values appear in the beginning of the rolling window calculations because there are not enough data points to compute the rolling average until the 10th data point.

# %%
nifty.rolling(window=10).median()
# Out:
#                    Close
# Date
# 2007-09-17           NaN
# 2007-09-18           NaN
# 2007-09-19           NaN
# 2007-09-20           NaN
# 2007-09-21           NaN
# ...                  ...
# 2023-11-16  19418.549805
# 2023-11-17  19434.424805
# 2023-11-20  19443.525391
# 2023-11-21  19559.500000
# 2023-11-22  19684.724609
#
# [3967 rows x 1 columns]

# %% [markdown]
# #### 19710.799805
# #### 2023-10-18	19710.799805
# #### 2023-10-19	19710.799805
# ##### 2023-10-20	19710.799805 why this value are same becasue it takes highest value of last 10 days

# %% [markdown]
# #### Mean: Average value calculated by summing all numbers and dividing by the count.dividing the period by last 10 days
# #### Median: Middle value of a sorted list; if even, the average of the two middle numbers. mid value of all the 10 days

# %%
nifty.rolling(window=10).max()
# Out:
#                    Close
# Date
# 2007-09-17           NaN
# 2007-09-18           NaN
# 2007-09-19           NaN
# 2007-09-20           NaN
# 2007-09-21           NaN
# ...                  ...
# 2023-11-16  19765.199219
# 2023-11-17  19765.199219
# 2023-11-20  19765.199219
# 2023-11-21  19783.400391
# 2023-11-22  19811.849609
#
# [3967 rows x 1 columns]

# %%
nifty.rolling(window=10,min_periods=5).max().head(30)
# Out:
#                   Close
# Date
# 2007-09-17          NaN
# 2007-09-18          NaN
# 2007-09-19          NaN
# 2007-09-20          NaN
# 2007-09-21  4837.549805
# 2007-09-24  4932.200195
# 2007-09-25  4938.850098
# 2007-09-26  4940.500000
# 2007-09-27  5000.549805
# 2007-09-28  5021.350098
# 2007-10-01  5068.950195
# 2007-10-03  5210.799805
# 2007-10-04  5210.799805
# 2007-10-05  5210.799805
# 2007-10-08  5210.799805
# 2007-10-09  5327.250000
# 2007-10-10  5441.450195
# 2007-10-11  5524.850098
# 2007-10-12  5524.850098
# 2007-10-15  5670.399902
# 2007-10-16  5670.399902
# 2007-10-17  5670.399902
# 2007-10-18  5670.399902
# 2007-10-19  5670.399902
# 2007-10-22  5670.399902
# 2007-10-23  5670.399902
# 2007-10-24  5670.399902
# 2007-10-25  5670.399902
# 2007-10-26  5702.299805
# 2007-10-29  5905.899902

# %% [markdown]
# ### the term "max" typically refers to the maximum (largest) value in the 'Close' column of your dataset. Specifically, it refers to the highest closing price recorded in the given time period. but here max is for last 10 days

# %% [markdown]
# ### Close Price:
#
# ### The "Close" price of a stock refers to the last traded price of the stock at the end of a trading day.

# %% [markdown]
# ### Adjusted Close Price:
#
# ### The "Adjusted Close" price, on the other hand, accounts for these corporate actions and other factors that might affect the stock price.

# %%
nifty["NIFTYMA50"] = nifty['Close'].rolling(window=5, min_periods=5).mean()

# %% [markdown]
# #   *******(window=80, min_periods=80).mean() play with the value of window and min period the more number the more data set it compares the less accuracy the small data it compares the more accurate when it compare between 500 days it is less accurate when compare with 5 or 10 days accuracy increases************

# %%
nifty.head(50)
# Out:
#                   Close    NIFTYMA50
# Date
# 2007-09-17  4494.649902          NaN
# 2007-09-18  4546.200195          NaN
# 2007-09-19  4732.350098          NaN
# 2007-09-20  4747.549805          NaN
# 2007-09-21  4837.549805  4671.659961
# 2007-09-24  4932.200195  4759.170020
# 2007-09-25  4938.850098  4837.700000
# 2007-09-26  4940.500000  4879.329980
# 2007-09-27  5000.549805  4929.929980
# 2007-09-28  5021.350098  4966.690039
# 2007-10-01  5068.950195  4994.040039
# 2007-10-03  5210.799805  5048.429980
# 2007-10-04  5208.649902  5102.059961
# 2007-10-05  5185.850098  5139.120020
# 2007-10-08  5085.100098  5151.870020
# 2007-10-09  5327.250000  5203.529980
# 2007-10-10  5441.450195  5249.660059
# 2007-10-11  5524.850098  5312.900098
# 2007-10-12  5428.250000  5361.380078
# 2007-10-15  5670.399902  5478.440039
# 2007-10-16  5668.049805  5546.600000
# 2007-10-17  5559.299805  5570.169922
# 2007-10-18  5351.000000  5535.399902
# 2007-10-19  5215.299805  5492.809863
# ...

# %%
nifty.plot(figsize=(24,20),fontsize=30)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
nifty.loc['2023-09'].plot(figsize=(24,20),fontsize=30)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
nifty_september_2023 = nifty.loc['2023-09']

# Calculate vertical distance between two lines
vertical_distance = nifty_september_2023['Close'] - nifty_september_2023['NIFTYMA50']

# Find maximum and minimum points
max_distance_date = vertical_distance.idxmax()
min_distance_date = vertical_distance.idxmin()
max_distance_value = vertical_distance.max()
min_distance_value = vertical_distance.min()

# Plot the data
plt.figure(figsize=(24, 20))
nifty_september_2023['Close'].plot(fontsize=30, label='Close')
nifty_september_2023['NIFTYMA50'].plot(fontsize=30, label='NIFTYMA50')

# Add red line for vertical distance
plt.axvline(x=max_distance_date, color='red', linestyle='--', linewidth=2, label=f'Max Gap: {max_distance_value:.2f}')
plt.axvline(x=min_distance_date, color='red', linestyle='--', linewidth=2, label=f'Min Gap: {min_distance_value:.2f}')

plt.legend(loc="upper left", fontsize=15)
plt.title('Nifty Data for September 2023', fontsize=30)
plt.xlabel('Date', fontsize=30)
plt.ylabel('Close Price', fontsize=30)
plt.show()

# %%
nifty["NIFTYMA200"] = nifty['Close'].rolling(window=200, min_periods=200).mean()

# %%
nifty
# Out:
#                    Close     NIFTYMA50    NIFTYMA200
# Date
# 2007-09-17   4494.649902           NaN           NaN
# 2007-09-18   4546.200195           NaN           NaN
# 2007-09-19   4732.350098           NaN           NaN
# 2007-09-20   4747.549805           NaN           NaN
# 2007-09-21   4837.549805   4671.659961           NaN
# ...                  ...           ...           ...
# 2023-11-16  19765.199219  19540.969922  18700.849570
# 2023-11-17  19731.800781  19608.269922  18708.917070
# 2023-11-20  19694.000000  19662.000000  18717.927324
# 2023-11-21  19783.400391  19729.969922  18728.822578
# 2023-11-22  19811.849609  19757.250000  18739.637080
#
# [3967 rows x 3 columns]

# %%
nifty.plot(figsize=(24,20),fontsize=30)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
nifty.loc['2023-09'].plot(figsize=(24,20),fontsize=30)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
nifty["Day"]=nifty.index.day_name()

# %%
nifty["quarter"]=nifty.index.quarter

# %%
nifty
# Out:
#                    Close     NIFTYMA50    NIFTYMA200        Day  quarter
# Date
# 2007-09-17   4494.649902           NaN           NaN     Monday        3
# 2007-09-18   4546.200195           NaN           NaN    Tuesday        3
# 2007-09-19   4732.350098           NaN           NaN  Wednesday        3
# 2007-09-20   4747.549805           NaN           NaN   Thursday        3
# 2007-09-21   4837.549805   4671.659961           NaN     Friday        3
# ...                  ...           ...           ...        ...      ...
# 2023-11-16  19765.199219  19540.969922  18700.849570   Thursday        4
# 2023-11-17  19731.800781  19608.269922  18708.917070     Friday        4
# 2023-11-20  19694.000000  19662.000000  18717.927324     Monday        4
# 2023-11-21  19783.400391  19729.969922  18728.822578    Tuesday        4
# 2023-11-22  19811.849609  19757.250000  18739.637080  Wednesday        4
#
# [3967 rows x 5 columns]

# %%
NIFTY = yf.download("^NSEI")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
nifty
# Out:
#                    Close     NIFTYMA50    NIFTYMA200        Day  quarter
# Date
# 2007-09-17   4494.649902           NaN           NaN     Monday        3
# 2007-09-18   4546.200195           NaN           NaN    Tuesday        3
# 2007-09-19   4732.350098           NaN           NaN  Wednesday        3
# 2007-09-20   4747.549805           NaN           NaN   Thursday        3
# 2007-09-21   4837.549805   4671.659961           NaN     Friday        3
# ...                  ...           ...           ...        ...      ...
# 2023-11-16  19765.199219  19540.969922  18700.849570   Thursday        4
# 2023-11-17  19731.800781  19608.269922  18708.917070     Friday        4
# 2023-11-20  19694.000000  19662.000000  18717.927324     Monday        4
# 2023-11-21  19783.400391  19729.969922  18728.822578    Tuesday        4
# 2023-11-22  19811.849609  19757.250000  18739.637080  Wednesday        4
#
# [3967 rows x 5 columns]

# %%
nifty=NIFTY.Close.to_frame()

# %%
nifty
# Out:
#                    Close
# Date
# 2007-09-17   4494.649902
# 2007-09-18   4546.200195
# 2007-09-19   4732.350098
# 2007-09-20   4747.549805
# 2007-09-21   4837.549805
# ...                  ...
# 2023-11-17  19731.800781
# 2023-11-20  19694.000000
# 2023-11-21  19783.400391
# 2023-11-22  19811.849609
# 2023-11-23  19816.550781
#
# [3968 rows x 1 columns]

# %%
all_days= pd.date_range(start="2010-12-31",end="2020-01-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
nifty
# Out:
#                    Close
# Date
# 2007-09-17   4494.649902
# 2007-09-18   4546.200195
# 2007-09-19   4732.350098
# 2007-09-20   4747.549805
# 2007-09-21   4837.549805
# ...                  ...
# 2023-11-17  19731.800781
# 2023-11-20  19694.000000
# 2023-11-21  19783.400391
# 2023-11-22  19811.849609
# 2023-11-23  19816.550781
#
# [3968 rows x 1 columns]

# %%
nifty=nifty.reindex(all_days)

# %%
nifty
# Out:
#                    Close
# 2010-12-31   6134.500000
# 2011-01-01           NaN
# 2011-01-02           NaN
# 2011-01-03   6157.600098
# 2011-01-04   6146.350098
# ...                  ...
# 2019-12-28           NaN
# 2019-12-29           NaN
# 2019-12-30  12255.849609
# 2019-12-31  12168.450195
# 2020-01-01  12182.500000
#
# [3289 rows x 1 columns]

# %% [markdown]
# #### now what you can see is all days also sat sun and national Holiday

# %% [markdown]
# # FORWARD FILL AND BACKWARD FILL"

# %% [markdown]
# #### FORWARD FILL TAKES PREVIOUS NUMBER AND FILLS IT
# #### BACKWARD FILL TAKES NEXT NUMBER AND FILLS IN THE SPACE OF NA

# %%
nifty.fillna(method="ffill") ##ffill reffers for foward fill
# Out:
#                    Close
# 2010-12-31   6134.500000
# 2011-01-01   6134.500000
# 2011-01-02   6134.500000
# 2011-01-03   6157.600098
# 2011-01-04   6146.350098
# ...                  ...
# 2019-12-28  12245.799805
# 2019-12-29  12245.799805
# 2019-12-30  12255.849609
# 2019-12-31  12168.450195
# 2020-01-01  12182.500000
#
# [3289 rows x 1 columns]

# %%
nifty.fillna(method="bfill") ##bfill reffers for backward fill
# Out:
#                    Close
# 2010-12-31   6134.500000
# 2011-01-01   6157.600098
# 2011-01-02   6157.600098
# 2011-01-03   6157.600098
# 2011-01-04   6146.350098
# ...                  ...
# 2019-12-28  12255.849609
# 2019-12-29  12255.849609
# 2019-12-30  12255.849609
# 2019-12-31  12168.450195
# 2020-01-01  12182.500000
#
# [3289 rows x 1 columns]

# %%
nifty = yf.download("^NSEI",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
nifty
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4855.700195   4481.549805   4837.549805
# 2007-09-24   4837.149902   5055.799805   4837.149902   5021.350098
# 2007-10-01   5021.500000   5261.350098   5001.350098   5185.850098
# 2007-10-08   5186.250000   5549.299805   5000.950195   5428.250000
# 2007-10-15   5428.350098   5736.799805   5101.750000   5215.299805
# ...                  ...           ...           ...           ...
# 2023-10-23  19521.599609  19556.849609  18837.849609  19047.250000
# 2023-10-30  19053.400391  19276.250000  18940.000000  19230.599609
# 2023-11-06  19345.849609  19464.400391  19309.699219  19425.349609
# 2023-11-13  19486.750000  19875.250000  19414.750000  19731.800781
# 2023-11-20  19731.150391  19875.150391  19670.500000  19818.000000
#
#                Adj Close   Volume
# Date
# 2007-09-17   4837.549805        0
# 2007-09-24   5021.350098        0
# 2007-10-01   5185.850098        0
# ...

# %% [markdown]
# ## cummalative returns Drawdowns etc

# %%
Reliance = yf.download("RELIANCE.NS",start="1975-01-01",end="2023-05-05")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
reliance=Reliance.Close.to_frame()

# %%
reliance
# Out:
#                   Close
# Date
# 1996-01-01    15.917452
# 1996-01-02    15.793671
# 1996-01-03    15.913584
# 1996-01-04    15.766594
# 1996-01-05    15.658285
# ...                 ...
# 2023-04-27  2377.050049
# 2023-04-28  2420.500000
# 2023-05-02  2441.050049
# 2023-05-03  2420.100098
# 2023-05-04  2448.000000
#
# [6872 rows x 1 columns]

# %%
reliance["d_returns"]=np.log(reliance.div(reliance.shift(1)))

# %%
reliance
# Out:
#                   Close  d_returns
# Date
# 1996-01-01    15.917452        NaN
# 1996-01-02    15.793671  -0.007807
# 1996-01-03    15.913584   0.007564
# 1996-01-04    15.766594  -0.009280
# 1996-01-05    15.658285  -0.006893
# ...                 ...        ...
# 2023-04-27  2377.050049   0.006309
# 2023-04-28  2420.500000   0.018114
# 2023-05-02  2441.050049   0.008454
# 2023-05-03  2420.100098  -0.008619
# 2023-05-04  2448.000000   0.011462
#
# [6872 rows x 2 columns]

# %%
reliance.dropna(inplace=True)

# %%
reliance.d_returns.sum()
# Out:
# 5.035610535164972

# %%
np.exp(reliance.d_returns.sum())
# Out:
# 153.79346026981116

# %% [markdown]
# so one ruppes invested in 1996 would be 153 RS

# %%
reliance["cummreturns"]=reliance.d_returns.cumsum().apply(np.exp)

# %%
reliance
# Out:
#                   Close  d_returns  cummreturns
# Date
# 1996-01-02    15.793671  -0.007807     0.992224
# 1996-01-03    15.913584   0.007564     0.999757
# 1996-01-04    15.766594  -0.009280     0.990522
# 1996-01-05    15.658285  -0.006893     0.983718
# 1996-01-08    15.031645  -0.040843     0.944350
# ...                 ...        ...          ...
# 2023-04-27  2377.050049   0.006309   149.336092
# 2023-04-28  2420.500000   0.018114   152.065797
# 2023-05-02  2441.050049   0.008454   153.356836
# 2023-05-03  2420.100098  -0.008619   152.040673
# 2023-05-04  2448.000000   0.011462   153.793460
#
# [6871 rows x 3 columns]

# %%
reliance.cummreturns.plot(figsize=(12,8),title="Reliance buy and hold",fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Average anual return of reliance

# %%
reliance.d_returns.mean()*252
# Out:
# 0.18468546861615093

# %%
reliance.d_returns.std()*np.sqrt(252)
# Out:
# 0.44146634971912996

# %% [markdown]
# how to calculate drawdawns

# %%
reliance["Cummmax"]=reliance.cummreturns.cummax()

# %%
reliance
# Out:
#                   Close  d_returns  cummreturns     Cummmax
# Date
# 1996-01-02    15.793671  -0.007807     0.992224    0.992224
# 1996-01-03    15.913584   0.007564     0.999757    0.999757
# 1996-01-04    15.766594  -0.009280     0.990522    0.999757
# 1996-01-05    15.658285  -0.006893     0.983718    0.999757
# 1996-01-08    15.031645  -0.040843     0.944350    0.999757
# ...                 ...        ...          ...         ...
# 2023-04-27  2377.050049   0.006309   149.336092  177.154618
# 2023-04-28  2420.500000   0.018114   152.065797  177.154618
# 2023-05-02  2441.050049   0.008454   153.356836  177.154618
# 2023-05-03  2420.100098  -0.008619   152.040673  177.154618
# 2023-05-04  2448.000000   0.011462   153.793460  177.154618
#
# [6871 rows x 4 columns]

# %%
reliance[["cummreturns","Cummmax"]].plot(figsize=(12,8),title="Reliance buy and hold Cummmax",fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
reliance["drawdown"]=reliance["Cummmax"]-reliance["cummreturns"]

# %%
reliance
# Out:
#                   Close  d_returns  cummreturns     Cummmax   drawdown
# Date
# 1996-01-02    15.793671  -0.007807     0.992224    0.992224   0.000000
# 1996-01-03    15.913584   0.007564     0.999757    0.999757   0.000000
# 1996-01-04    15.766594  -0.009280     0.990522    0.999757   0.009235
# 1996-01-05    15.658285  -0.006893     0.983718    0.999757   0.016039
# 1996-01-08    15.031645  -0.040843     0.944350    0.999757   0.055407
# ...                 ...        ...          ...         ...        ...
# 2023-04-27  2377.050049   0.006309   149.336092  177.154618  27.818526
# 2023-04-28  2420.500000   0.018114   152.065797  177.154618  25.088821
# 2023-05-02  2441.050049   0.008454   153.356836  177.154618  23.797782
# 2023-05-03  2420.100098  -0.008619   152.040673  177.154618  25.113944
# 2023-05-04  2448.000000   0.011462   153.793460  177.154618  23.361157
#
# [6871 rows x 5 columns]

# %%
reliance.drawdown.max()
# Out:
# 45.17581511765498

# %%
reliance.drawdown.idxmax()
# Out:
# Timestamp('2020-03-23 00:00:00')

# %%
reliance.loc[(reliance.index=='2020-03-23')]
# Out:
#                  Close  d_returns  cummreturns     Cummmax   drawdown
# Date
# 2020-03-23  875.748779  -0.141032    55.018152  100.193967  45.175815

# %%
reliance.loc[(reliance.index<='2020-03-23')]
# Out:
#                   Close  d_returns  cummreturns     Cummmax   drawdown
# Date
# 1996-01-02    15.793671  -0.007807     0.992224    0.992224   0.000000
# 1996-01-03    15.913584   0.007564     0.999757    0.999757   0.000000
# 1996-01-04    15.766594  -0.009280     0.990522    0.999757   0.009235
# 1996-01-05    15.658285  -0.006893     0.983718    0.999757   0.016039
# 1996-01-08    15.031645  -0.040843     0.944350    0.999757   0.055407
# ...                 ...        ...          ...         ...        ...
# 2020-03-17   998.534912  -0.007610    62.732083  100.193967  37.461884
# 2020-03-18   959.405762  -0.039975    60.273828  100.193967  39.920138
# 2020-03-19   909.082825  -0.053878    57.112334  100.193967  43.081633
# 2020-03-20  1008.391479   0.103676    63.351313  100.193967  36.842653
# 2020-03-23   875.748779  -0.141032    55.018152  100.193967  45.175815
#
# [6099 rows x 5 columns]

# %%
reliance["drawdown%"]=(reliance["Cummmax"]-reliance["cummreturns"])/reliance["Cummmax"]

# %%
reliance
# Out:
#                   Close  d_returns  cummreturns     Cummmax   drawdown  \
# Date
# 1996-01-02    15.793671  -0.007807     0.992224    0.992224   0.000000
# 1996-01-03    15.913584   0.007564     0.999757    0.999757   0.000000
# 1996-01-04    15.766594  -0.009280     0.990522    0.999757   0.009235
# 1996-01-05    15.658285  -0.006893     0.983718    0.999757   0.016039
# 1996-01-08    15.031645  -0.040843     0.944350    0.999757   0.055407
# ...                 ...        ...          ...         ...        ...
# 2023-04-27  2377.050049   0.006309   149.336092  177.154618  27.818526
# 2023-04-28  2420.500000   0.018114   152.065797  177.154618  25.088821
# 2023-05-02  2441.050049   0.008454   153.356836  177.154618  23.797782
# 2023-05-03  2420.100098  -0.008619   152.040673  177.154618  25.113944
# 2023-05-04  2448.000000   0.011462   153.793460  177.154618  23.361157
#
#             drawdown%
# Date
# 1996-01-02   0.000000
# 1996-01-03   0.000000
# 1996-01-04   0.009237
# ...

# %%
reliance["drawdown%"].max()
# Out:
# 0.7322938890501461

# %%
reliance["drawdown%"].idxmax()
# Out:
# Timestamp('1998-10-20 00:00:00')

# %%
reliance.loc[(reliance.index<='1998-10-20')]
# Out:
#                 Close  d_returns  cummreturns   Cummmax  drawdown  drawdown%
# Date
# 1996-01-02  15.793671  -0.007807     0.992224  0.992224  0.000000   0.000000
# 1996-01-03  15.913584   0.007564     0.999757  0.999757  0.000000   0.000000
# 1996-01-04  15.766594  -0.009280     0.990522  0.999757  0.009235   0.009237
# 1996-01-05  15.658285  -0.006893     0.983718  0.999757  0.016039   0.016043
# 1996-01-08  15.031645  -0.040843     0.944350  0.999757  0.055407   0.055421
# ...               ...        ...          ...       ...       ...        ...
# 1998-10-14  16.965721   0.058205     1.065857  3.678250  2.612394   0.710227
# 1998-10-15  16.462860  -0.030088     1.034265  3.678250  2.643986   0.718816
# 1998-10-16  16.578905   0.007024     1.041555  3.678250  2.636695   0.716834
# 1998-10-19  16.323608  -0.015519     1.025516  3.678250  2.652734   0.721195
# 1998-10-20  15.673758  -0.040625     0.984690  3.678250  2.693560   0.732294
#
# [731 rows x 6 columns]

# %% [markdown]
# ## SMA STRATEGY

# %% [markdown]
# SMAs are often used to determine trend direction. If the SMA is moving up, the trend is up. If the SMA is moving down, the trend is down. A 200-bar SMA is common proxy for the long term trend. 50-bar SMAs are typically used to gauge the intermediate trend. Shorter period SMAs can be used to determine shorter term trends.

# %%
data=reliance.Close.loc[(reliance.index>='1998-10-20')]

# %%
data
# Out:
# Date
# 1998-10-20      15.673758
# 1998-10-21      15.673758
# 1998-10-22      16.400970
# 1998-10-23      16.509279
# 1998-10-26      17.832188
#                  ...
# 2023-04-27    2377.050049
# 2023-04-28    2420.500000
# 2023-05-02    2441.050049
# 2023-05-03    2420.100098
# 2023-05-04    2448.000000
# Name: Close, Length: 6141, dtype: float64

# %%
data=data.to_frame()

# %%
data
# Out:
#                   Close
# Date
# 1998-10-20    15.673758
# 1998-10-21    15.673758
# 1998-10-22    16.400970
# 1998-10-23    16.509279
# 1998-10-26    17.832188
# ...                 ...
# 2023-04-27  2377.050049
# 2023-04-28  2420.500000
# 2023-05-02  2441.050049
# 2023-05-03  2420.100098
# 2023-05-04  2448.000000
#
# [6141 rows x 1 columns]

# %%
sma_s=50
sma_l=100
sma_L=200

# %%
data["Sma_S"]= data.Close.rolling(sma_s).mean()
data["Sma_l"]= data.Close.rolling(sma_l).mean()
data["Sma_L"]= data.Close.rolling(sma_L).mean()

# %%
data
# Out:
#                   Close        Sma_S        Sma_l        Sma_L
# Date
# 1998-10-20    15.673758          NaN          NaN          NaN
# 1998-10-21    15.673758          NaN          NaN          NaN
# 1998-10-22    16.400970          NaN          NaN          NaN
# 1998-10-23    16.509279          NaN          NaN          NaN
# 1998-10-26    17.832188          NaN          NaN          NaN
# ...                 ...          ...          ...          ...
# 2023-04-27  2377.050049  2333.185010  2422.093008  2471.535510
# 2023-04-28  2420.500000  2334.862012  2419.065007  2471.578760
# 2023-05-02  2441.050049  2337.216011  2416.254009  2471.843510
# 2023-05-03  2420.100098  2338.056011  2413.630510  2471.987010
# 2023-05-04  2448.000000  2338.377012  2411.208511  2472.107511
#
# [6141 rows x 4 columns]

# %%
data.plot(figsize=(12,8),title="Reliance-SMA{} | SMA{}".format(sma_s,sma_l,sma_L),fontsize=12)
# Out:
# <Axes: title={'center': 'Reliance-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="Reliance-SMA{} | SMA{}".format(sma_s,sma_l,sma_L),fontsize=12)
# Out:
# <Axes: title={'center': 'Reliance-SMA50 | SMA100'}, xlabel='Date'>

# %% [markdown]
# ### now you can see here sma_s & sma_l are in uptrend so you can predict where the stock will follow according to research 200 is more preferable for a long term trade

# %%
data.loc["2017"].plot(figsize=(12,8),title="Reliance-SMA{} | SMA{}".format(sma_s,sma_l,sma_L),fontsize=12)
# Out:
# <Axes: title={'center': 'Reliance-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                   Close        Sma_S        Sma_l        Sma_L
# Date
# 1999-07-26    26.744413    27.746884    24.318849    21.731016
# 1999-07-27    26.427225    27.704644    24.351032    21.784783
# 1999-07-28    27.084810    27.678495    24.399075    21.841838
# 1999-07-29    27.819759    27.691492    24.461275    21.898932
# 1999-07-30    27.711452    27.728627    24.525486    21.954943
# ...                 ...          ...          ...          ...
# 2023-04-27  2377.050049  2333.185010  2422.093008  2471.535510
# 2023-04-28  2420.500000  2334.862012  2419.065007  2471.578760
# 2023-05-02  2441.050049  2337.216011  2416.254009  2471.843510
# 2023-05-03  2420.100098  2338.056011  2413.630510  2471.987010
# 2023-05-04  2448.000000  2338.377012  2411.208511  2472.107511
#
# [5942 rows x 4 columns]

# %%
data["position"]=np.where(data["Sma_S"]>data["Sma_l"],1,-1)

# %% [markdown]
# ### if sma_s is large than sma_l then return one or else return -1

# %%
data
# Out:
#                   Close        Sma_S        Sma_l        Sma_L  position
# Date
# 1999-07-26    26.744413    27.746884    24.318849    21.731016         1
# 1999-07-27    26.427225    27.704644    24.351032    21.784783         1
# 1999-07-28    27.084810    27.678495    24.399075    21.841838         1
# 1999-07-29    27.819759    27.691492    24.461275    21.898932         1
# 1999-07-30    27.711452    27.728627    24.525486    21.954943         1
# ...                 ...          ...          ...          ...       ...
# 2023-04-27  2377.050049  2333.185010  2422.093008  2471.535510        -1
# 2023-04-28  2420.500000  2334.862012  2419.065007  2471.578760        -1
# 2023-05-02  2441.050049  2337.216011  2416.254009  2471.843510        -1
# 2023-05-03  2420.100098  2338.056011  2413.630510  2471.987010        -1
# 2023-05-04  2448.000000  2338.377012  2411.208511  2472.107511        -1
#
# [5942 rows x 5 columns]

# %%
data.loc[:,["Sma_S","Sma_l","position"]].plot(figsize=(12,8),title="Reliance-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'Reliance-SMA50 | SMA100'}, xlabel='Date'>

# %% [markdown]
# ### For 2016

# %%
data.loc["2016",["Sma_S","Sma_l","position"]].plot(figsize=(12,8),title="Reliance-SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'Reliance-SMA50 | SMA100'}, xlabel='Date'>

# %% [markdown]
# ### -1 referes to have a short position and +1 refers us to keep a long position

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))
#returnsb&h= returns buy and hold

# %%
data["Strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                   Close        Sma_S        Sma_l        Sma_L  position  \
# Date
# 1999-07-26    26.744413    27.746884    24.318849    21.731016         1
# 1999-07-27    26.427225    27.704644    24.351032    21.784783         1
# 1999-07-28    27.084810    27.678495    24.399075    21.841838         1
# 1999-07-29    27.819759    27.691492    24.461275    21.898932         1
# 1999-07-30    27.711452    27.728627    24.525486    21.954943         1
# ...                 ...          ...          ...          ...       ...
# 2023-04-27  2377.050049  2333.185010  2422.093008  2471.535510        -1
# 2023-04-28  2420.500000  2334.862012  2419.065007  2471.578760        -1
# 2023-05-02  2441.050049  2337.216011  2416.254009  2471.843510        -1
# 2023-05-03  2420.100098  2338.056011  2413.630510  2471.987010        -1
# 2023-05-04  2448.000000  2338.377012  2411.208511  2472.107511        -1
#
#             returnsb&h  Strategy
# Date
# 1999-07-26         NaN       NaN
# ...

# %%
 data.dropna(inplace=True)

# %%
data[["returnsb&h","Strategy"]].sum()
# Out:
# returnsb&h    4.516701
# Strategy      2.656985
# dtype: float64

# %% [markdown]
# ### Returnsb&h tells us about when to buy and hold it tells about to keep a long position
# ### where Strategy tells us about is when to take the short position

# %%
data[["returnsb&h","Strategy"]].sum().apply(np.exp) # what 1 RS would be if you only have insvested
# Out:
# returnsb&h    91.533135
# Strategy      14.253244
# dtype: float64

# %%
data[["returnsb&h","Strategy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.396201
# Strategy      0.396321
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Strategy adjusted with long position

# %%
data["position2"]=np.where(data["Sma_S"]>data["Sma_l"],1,0)

# %%
data["Strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","Strategy2"]].sum()
# Out:
# returnsb&h    4.528632
# Strategy2     3.598774
# dtype: float64

# %%
data[["returnsb&h","Strategy2"]].sum().apply(np.exp) # what 1 RS would be if you only have insvested
# Out:
# returnsb&h    92.631746
# Strategy2     36.553380
# dtype: float64

# %%
data[["returnsb&h","Strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.396225
# Strategy2     0.326198
# dtype: float64

# %%
### strategy 2 is sbetter than strategy 1 because less risk 
data[["Strategy","Strategy2"]].std()*np.sqrt(252)
# Out:
# Strategy     0.396346
# Strategy2    0.326198
# dtype: float64

# %% [markdown]
# ## Creating your first function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]= np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)
    return ret,std # how much return is given on how much risk

# %%
test_strategy("MSFT","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (0.39097954932295986, 0.2906766831415824)

# %%
test_strategy("AAPL","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (16.540320732436786, 0.3669968290380402)

# %%
test_strategy("SPY","2000-01-01","2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (4.766371508372407, 0.1878794718595858)
